# %%
# Bismillah

# %%
import pandas_datareader.data as web
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
#import mpld3
#mpld3.enable_notebook()

# %%
start = dt.datetime(2020, 1, 1)
end = dt.datetime(2020, 9, 7)
tickers = ['GOOG', 'AMZN', 'AAPL']
cc = 'BTC-USD' # Bitcoin in USD

# %%
for ticker in tickers:
    data = web.DataReader(ticker, 'yahoo', start, end)
    data.to_csv('{}.csv'.format(ticker))

# %%
data = pd.read_csv('AMZN.csv', parse_dates = True, index_col = 'Date')
data
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2019-12-31  1853.260010  1832.229980  1842.000000  1847.839966  2506500
# 2020-01-02  1898.010010  1864.150024  1875.000000  1898.010010  4029000
# 2020-01-03  1886.199951  1864.500000  1864.500000  1874.969971  3764400
# 2020-01-06  1903.689941  1860.000000  1860.000000  1902.880005  4061800
# 2020-01-07  1913.890015  1892.040039  1904.500000  1906.859985  4044900
# ...                 ...          ...          ...          ...      ...
# 2020-08-31  3495.000000  3405.000000  3408.989990  3450.959961  4185900
# 2020-09-01  3513.870117  3467.000000  3489.580078  3499.120117  3432200
# 2020-09-02  3552.250000  3486.689941  3547.000000  3531.449951  3931500
# 2020-09-03  3488.409912  3303.000000  3485.000000  3368.000000  8161100
# 2020-09-04  3381.500000  3111.129883  3318.000000  3294.620117  8781800
#
#               Adj Close
# Date
# 2019-12-31  1847.839966
# 2020-01-02  1898.010010
# 2020-01-03  1874.969971
# 2020-01-06  1902.880005
# 2020-01-07  1906.859985
# ...                 ...
# 2020-08-31  3450.959961
# 2020-09-01  3499.120117
# 2020-09-02  3531.449951
# 2020-09-03  3368.000000
# 2020-09-04  3294.620117
#
# [173 rows x 6 columns]

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan = 4, colspan = 1, title = 'Amazon')
ax2 = plt.subplot2grid((7, 1), (4, 0), rowspan = 3, colspan = 1, sharex = ax1)

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan = 4, colspan = 1, title = 'Amazon')
ax2 = plt.subplot2grid((7, 1), (4, 0), rowspan = 3, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price')
ax2.bar(data.index, data['Volume'], label = 'Volume')
# Out:
# <BarContainer object of 173 artists>

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan = 4, colspan = 1, title = 'Amazon')
ax2 = plt.subplot2grid((7, 1), (4, 0), rowspan = 3, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price')
ax2.bar(data.index, data['Volume'], label = 'Volume')

ax1.legend()
ax2.legend(loc = 'upper right')
plt.show()

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan = 4, colspan = 1, title = 'Amazon')
ax2 = plt.subplot2grid((7, 1), (5, 0), rowspan = 2, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price')
ax2.bar(data.index, data['Volume'], label = 'Volume')

ax1.legend()
ax2.legend(loc = 'upper right')
plt.show()

# %%
import matplotlib.dates as mdates

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan = 4, colspan = 1, title = 'Amazon - 2020')
ax2 = plt.subplot2grid((7, 1), (5, 0), rowspan = 2, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price')
ax2.bar(data.index, data['Volume'], label = 'Volume')

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))
ax2.set_xlabel('Date (Month - Day)')

ax1.legend()
ax2.legend(loc = 'upper right')
plt.show()

# %%
from matplotlib import style
style.use('ggplot') # try 'ggplot and seaborn'

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan = 4, colspan = 1, title = 'Amazon - 2020')
ax2 = plt.subplot2grid((7, 1), (5, 0), rowspan = 2, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price')
ax2.bar(data.index, data['Volume'], label = 'Volume')

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))
ax2.set_xlabel('Date (Month - Day)')

ax1.legend()
ax2.legend(loc = 'upper right')
plt.savefig('Amazon-2020')
plt.show()

# %%
data['Adj Close']
# Out:
# Date
# 2019-12-31    1847.839966
# 2020-01-02    1898.010010
# 2020-01-03    1874.969971
# 2020-01-06    1902.880005
# 2020-01-07    1906.859985
#                  ...
# 2020-08-31    3450.959961
# 2020-09-01    3499.120117
# 2020-09-02    3531.449951
# 2020-09-03    3368.000000
# 2020-09-04    3294.620117
# Name: Adj Close, Length: 173, dtype: float64

# %%
3294.620117 / 1847.839966 # Almost 78 percent return in 09 months time.
# Out:
# 1.7829574950323377

# %% [markdown]
# ## Moving Average:

# %%
start = dt.datetime(2015, 1, 1)
end = dt.datetime(2020, 9, 7)
ticker = 'AAPL'

# %%
data = web.DataReader(ticker, 'yahoo', start, end)
data
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2014-12-31   28.282499   27.552500   28.205000   27.594999  165613600.0
# 2015-01-02   27.860001   26.837500   27.847500   27.332500  212818400.0
# 2015-01-05   27.162500   26.352501   27.072500   26.562500  257142000.0
# 2015-01-06   26.857500   26.157499   26.635000   26.565001  263188400.0
# 2015-01-07   27.049999   26.674999   26.799999   26.937500  160423600.0
# ...                ...         ...         ...         ...          ...
# 2020-08-31  131.000000  126.000000  127.580002  129.039993  225702700.0
# 2020-09-01  134.800003  130.529999  132.759995  134.179993  151948100.0
# 2020-09-02  137.979996  127.000000  137.589996  131.399994  200119000.0
# 2020-09-03  128.839996  120.500000  126.910004  120.879997  257599600.0
# 2020-09-04  123.699997  110.889999  120.070000  120.959999  332607200.0
#
#              Adj Close
# Date
# 2014-12-31   24.915262
# 2015-01-02   24.678251
# 2015-01-05   23.983025
# 2015-01-06   23.985279
# 2015-01-07   24.321608
# ...                ...
# 2020-08-31  127.677971
# 2020-09-01  132.763748
# 2020-09-02  130.013062
# 2020-09-03  119.604111
# 2020-09-04  119.683266
#
# [1431 rows x 6 columns]

# %%
data['SMA20'] = data['Adj Close'].rolling(20).mean()
# 2015-01-27  24.635359        NaN     NaN
# 2015-01-28  26.028078        NaN     NaN
# 2015-01-29  26.838413  24.897765     NaN
# 2015-01-30  26.445660  24.974285     NaN
# 2015-02-02  26.777472  25.079246     NaN
# 2015-02-03  26.781984  25.219194     NaN
# 2015-02-04  26.987391  25.369299     NaN
# 2015-02-05  27.180014  25.512220     NaN
# 2015-02-06  26.951132  25.596971     NaN
# 2015-02-09  27.130157  25.689320     NaN
# 2015-02-10  27.651369  25.838879     NaN
# 2015-02-11  28.299482  26.009896     NaN
# 2015-02-12  28.657532  26.203555     NaN

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan = 4, colspan = 1, title = ticker)
ax2 = plt.subplot2grid((7, 1), (5, 0), rowspan = 2, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price', alpha = 0.75)
ax1.plot(data['SMA20'], label = 'SMA20')
ax1.plot(data['SMA120'], label = 'SMA120')

ax2.bar(data.index, data['Volume'], label = 'Volume')

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y, %m'))

ax2.set_xlabel('Date (Year - Month)')

ax1.legend()
ax2.legend(loc = 'upper right')

# when SMA20 goes above SMA120, it signal to buy as it suggests that there is a recent surge in buying pressure, 
# that is, investors are willing to buy it more recently as compared to the long-term trend. By the same token, 
# SMA20 going below SMA120 suggests that the price is decreasing recently as compared to long-term trend so we 
# should sell it if we already hold it or maybe short sell it if we don't already own it. Explain short selling
# to the students.

# %%
data = data.drop(columns = ['High', 'Low', 'Open', 'Close']) # remove the unneeded columns.

# %%
data
# Out:
#                  Volume   Adj Close       SMA20     SMA120
# Date
# 2014-12-31  165613600.0   24.915262         NaN        NaN
# 2015-01-02  212818400.0   24.678251         NaN        NaN
# 2015-01-05  257142000.0   23.983025         NaN        NaN
# 2015-01-06  263188400.0   23.985279         NaN        NaN
# 2015-01-07  160423600.0   24.321608         NaN        NaN
# ...                 ...         ...         ...        ...
# 2020-08-31  225702700.0  127.677971  116.445662  84.878069
# 2020-09-01  151948100.0  132.763748  117.668239  85.475046
# 2020-09-02  200119000.0  130.013062  118.733652  85.988072
# 2020-09-03  257599600.0  119.604111  119.088986  86.487739
# 2020-09-04  332607200.0  119.683266  119.576163  86.966211
#
# [1431 rows x 4 columns]

# %%
data['price_yesterday'] = data['Adj Close'].shift(1)
data.head()

# the adj. close values have been shifted one day forward. Subtracting price_yesterday from adj. close in the same
# row gives absolute change. Dividing this absolute change by price_yesterday gives net percentage change.
# Out:
#                  Volume  Adj Close  SMA20  SMA120  price_yesterday
# Date
# 2014-12-31  165613600.0  24.915262    NaN     NaN              NaN
# 2015-01-02  212818400.0  24.678251    NaN     NaN        24.915262
# 2015-01-05  257142000.0  23.983025    NaN     NaN        24.678251
# 2015-01-06  263188400.0  23.985279    NaN     NaN        23.983025
# 2015-01-07  160423600.0  24.321608    NaN     NaN        23.985279

# %%
(24.714506 - 24.951866) /  24.951866

# every $1 invested in this stock has lost $0.0095 during this one day.
# we can divide the adj close today by price_yesterday, which gives the today worth of $1 invested in this stock
# yesterday as shown below.
# Out:
# -0.009512715401725824

# %%
24.714506 /  24.951866

# this gives us the today's worth of $1 invested in this stock yersterday.
# subtracting 1 from this would give the following.
# Out:
# 0.9904872845982742

# %%
0.9904872845982742 - 1

# this gives the amount lost by investing $1 in this stock as above.
# so, (current price - previous price) / previous price gives us the net gain/loss per $ of investment. In this
# example, it gives us -0.00951, which can be converted to percentage by multiplying it with 100 which then gives
# -0.951%, thus, every $100 invested lost $0.95. Alternatively, we can divide current price by previous price
# (current price / previous price) which gives us the current worth of $1 invested. In this case it is 0.9904 and
# it means that $1 invested in this stock worths $0.9904 today. This can be converted to percentage by multiplying
# with 100 which gives 99.04% which means $100 invested in this stock worths $99.04 today. When 1 subtracted from
# 0.9904, it gives -0.0095 which is the same figure that we earleir obtained by (current price - previous price) / 
# previous price.
# Out:
# -0.009512715401725824

# %%
data['change'] = data['Adj Close'] / data['price_yesterday']

# it gives the today worth of $1 dollar invested yesterday since they are based on daily adj close prices.

# %%
data.head()
# Out:
#                  Volume  Adj Close  SMA20  SMA120  price_yesterday    change
# Date
# 2014-12-31  165613600.0  24.915262    NaN     NaN              NaN       NaN
# 2015-01-02  212818400.0  24.678251    NaN     NaN        24.915262  0.990487
# 2015-01-05  257142000.0  23.983025    NaN     NaN        24.678251  0.971828
# 2015-01-06  263188400.0  23.985279    NaN     NaN        23.983025  1.000094
# 2015-01-07  160423600.0  24.321608    NaN     NaN        23.985279  1.014022

# %%
data['invested_SMA'] = np.where(data['SMA20'] > data['SMA120'], 1, 0)
data.head()
# Out:
#                  Volume  Adj Close  SMA20  SMA120  price_yesterday    change  \
# Date
# 2014-12-31  165613600.0  24.915262    NaN     NaN              NaN       NaN
# 2015-01-02  212818400.0  24.678251    NaN     NaN        24.915262  0.990487
# 2015-01-05  257142000.0  23.983025    NaN     NaN        24.678251  0.971828
# 2015-01-06  263188400.0  23.985279    NaN     NaN        23.983025  1.000094
# 2015-01-07  160423600.0  24.321608    NaN     NaN        23.985279  1.014022
#
#             invested_SMA
# Date
# 2014-12-31             0
# 2015-01-02             0
# 2015-01-05             0
# 2015-01-06             0
# 2015-01-07             0

# %%
data['invested_SMA'].describe
# Out:
# <bound method NDFrame.describe of Date
# 2014-12-31    0
# 2015-01-02    0
# 2015-01-05    0
# 2015-01-06    0
# 2015-01-07    0
#              ..
# 2020-08-31    1
# 2020-09-01    1
# 2020-09-02    1
# 2020-09-03    1
# 2020-09-04    1
# Name: invested_SMA, Length: 1431, dtype: int64>

# %%
data['invested_SMA'] == 1
# Out:
# Date
# 2014-12-31    False
# 2015-01-02    False
# 2015-01-05    False
# 2015-01-06    False
# 2015-01-07    False
#               ...
# 2020-08-31     True
# 2020-09-01     True
# 2020-09-02     True
# 2020-09-03     True
# 2020-09-04     True
# Name: invested_SMA, Length: 1431, dtype: bool

# %%
data[data['invested_SMA'] == 1]

# Will produce only that part of the data frame where invested_SMA is equal to 1.
# Out:
#                  Volume   Adj Close       SMA20     SMA120  price_yesterday  \
# 2015-01-02  212818400.0   24.678251         NaN        NaN        24.915262
# 2015-01-05  257142000.0   23.983025         NaN        NaN        24.678251
# 2015-01-06  263188400.0   23.985279         NaN        NaN        23.983025
# 2015-01-07  160423600.0   24.321608         NaN        NaN        23.985279
# ...                 ...         ...         ...        ...              ...
# 2020-08-31  225702700.0  127.677971  116.445662  84.878069       123.490158
# 2020-09-01  151948100.0  132.763748  117.668239  85.475046       127.677971
# 2020-09-02  200119000.0  130.013062  118.733652  85.988072       132.763748
# 2020-09-03  257599600.0  119.604111  119.088986  86.487739       130.013062
# 2020-09-04  332607200.0  119.683266  119.576163  86.966211       119.604111
#
#               change  invested_SMA  buy_and_hold
# Date
# 2014-12-31       NaN             0           NaN
# 2015-01-02  0.990487             0      0.990487
# 2015-01-05  0.971828             0      0.962584
# 2015-01-06  1.000094             0      0.962674
# 2015-01-07  1.014022             0      0.976173
# ...              ...           ...           ...
# 2020-08-31  1.033912             1      5.124488
# 2020-09-01  1.039833             1      5.328611
# 2020-09-02  0.979281             1      5.218210
# 2020-09-03  0.919939             1      4.800436
# 2020-09-04  1.000662             1      4.803613
#
# [1431 rows x 8 columns]

# %%
# Computation of np.cumproduct:
0.990487 * 0.971829
# Out:
# 0.962583990723

# %%
0.962583990723 * 1.000094
# Out:
# 0.9626744736181281

# %%
0.9626744736181281 * 1.014022

# so, first day 'change' is multiplied with the second day 'change' to get the second day cumulative product. Then
# this second day cumulative product is multiplied with the third day 'change' to get the third day cumulative 
# product. The last day cumulative product at the end of period shows the last day worth of $1 invested on the 
# first day of the period.
# Out:
# 0.9761730950872014

# %%
data
# Out:
#                  Volume   Adj Close       SMA20     SMA120  price_yesterday  \
# Date
# 2014-12-31  165613600.0   24.915262         NaN        NaN              NaN
# 2015-01-02  212818400.0   24.678251         NaN        NaN        24.915262
# 2015-01-05  257142000.0   23.983025         NaN        NaN        24.678251
# 2015-01-06  263188400.0   23.985279         NaN        NaN        23.983025
# 2015-01-07  160423600.0   24.321608         NaN        NaN        23.985279
# ...                 ...         ...         ...        ...              ...
# 2020-08-31  225702700.0  127.677971  116.445662  84.878069       123.490158
# 2020-09-01  151948100.0  132.763748  117.668239  85.475046       127.677971
# 2020-09-02  200119000.0  130.013062  118.733652  85.988072       132.763748
# 2020-09-03  257599600.0  119.604111  119.088986  86.487739       130.013062
# 2020-09-04  332607200.0  119.683266  119.576163  86.966211       119.604111
#
#               change  invested_SMA  buy_and_hold
# Date
# 2014-12-31       NaN             0           NaN
# 2015-01-02  0.990487             0      0.990487
# 2015-01-05  0.971828             0      0.962584
# 2015-01-06  1.000094             0      0.962674
# 2015-01-07  1.014022             0      0.976173
# ...              ...           ...           ...
# 2020-08-31  1.033912             1      5.124488
# 2020-09-01  1.039833             1      5.328611
# 2020-09-02  0.979281             1      5.218210
# 2020-09-03  0.919939             1      4.800436
# 2020-09-04  1.000662             1      4.803613
#
# [1431 rows x 8 columns]

# %%
119.859116 / 24.951864 

# its the same as the last value in the buy and hold column and in both cases it can be interpreted as: $1 invested
# would have grown to $ 4.8 at the end of the period.
# Out:
# 4.8036137099817475

# %%
data.head()
# Out:
#                  Volume  Adj Close  SMA20  SMA120  price_yesterday    change  \
# Date
# 2014-12-31  165613600.0  24.915262    NaN     NaN              NaN       NaN
# 2015-01-02  212818400.0  24.678251    NaN     NaN        24.915262  0.990487
# 2015-01-05  257142000.0  23.983025    NaN     NaN        24.678251  0.971828
# 2015-01-06  263188400.0  23.985279    NaN     NaN        23.983025  1.000094
# 2015-01-07  160423600.0  24.321608    NaN     NaN        23.985279  1.014022
#
#             invested_SMA  buy_and_hold
# Date
# 2014-12-31             0           NaN
# 2015-01-02             0      0.990487
# 2015-01-05             0      0.962584
# 2015-01-06             0      0.962674
# 2015-01-07             0      0.976173

# %%
sma
# Out:
#                  Volume   Adj Close       SMA20     SMA120  price_yesterday  \
# Date
# 2015-06-23  121075600.0   28.906944   29.281624  28.161932        29.038931
# 2015-06-24  221123600.0   29.152712   29.236909  28.197244        28.906944
# 2015-06-25  127752400.0   29.013899   29.188210  28.233374        29.152712
# 2015-06-26  176267200.0   28.843229   29.148046  28.273876        29.013899
# 2015-06-29  196645600.0   28.338049   29.079665  28.310149        28.843229
# ...                 ...         ...         ...        ...              ...
# 2020-08-31  225702700.0  127.677971  116.445662  84.878069       123.490158
# 2020-09-01  151948100.0  132.763748  117.668239  85.475046       127.677971
# 2020-09-02  200119000.0  130.013062  118.733652  85.988072       132.763748
# 2020-09-03  257599600.0  119.604111  119.088986  86.487739       130.013062
# 2020-09-04  332607200.0  119.683266  119.576163  86.966211       119.604111
#
#               change  invested_SMA
# Date
# 2015-06-23  0.995455             1
# 2015-06-24  1.008502             1
# 2015-06-25  0.995238             1
# 2015-06-26  0.994118             1
# 2015-06-29  0.982485             1
# ...              ...           ...
# 2020-08-31  1.033912             1
# 2020-09-01  1.039833             1
# 2020-09-02  0.979281             1
# 2020-09-03  0.919939             1
# 2020-09-04  1.000662             1
#
# [952 rows x 7 columns]

# %%
sma['return'] = np.cumprod(sma['change'])
sma

# following this strategy of buying when SMA20 is greater than SMA120 would result in this return which can be 
# interpreted as: $1 investment would have grown to $2.91 dollars at the end of the period using this strategy.
# Out:
# <ipython-input-145-a56778701b3c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sma['return'] = np.cumprod(sma['change'])
#                  Volume   Adj Close       SMA20     SMA120  price_yesterday  \
# Date
# 2015-06-23  121075600.0   28.906944   29.281624  28.161932        29.038931
# 2015-06-24  221123600.0   29.152712   29.236909  28.197244        28.906944
# 2015-06-25  127752400.0   29.013899   29.188210  28.233374        29.152712
# 2015-06-26  176267200.0   28.843229   29.148046  28.273876        29.013899
# 2015-06-29  196645600.0   28.338049   29.079665  28.310149        28.843229
# ...                 ...         ...         ...        ...              ...
# 2020-08-31  225702700.0  127.677971  116.445662  84.878069       123.490158
# 2020-09-01  151948100.0  132.763748  117.668239  85.475046       127.677971
# 2020-09-02  200119000.0  130.013062  118.733652  85.988072       132.763748
# 2020-09-03  257599600.0  119.604111  119.088986  86.487739       130.013062
# 2020-09-04  332607200.0  119.683266  119.576163  86.966211       119.604111
#
#               change  invested_SMA    return
# Date
# 2015-06-23  0.995455             1  0.995455
# 2015-06-24  1.008502             1  1.003918
# 2015-06-25  0.995238             1  0.999138
# 2015-06-26  0.994118             1  0.993261
# 2015-06-29  0.982485             1  0.975864
# ...              ...           ...       ...
# 2020-08-31  1.033912             1  3.106929
# 2020-09-01  1.039833             1  3.230687
# 2020-09-02  0.979281             1  3.163752
# 2020-09-03  0.919939             1  2.910459
# 2020-09-04  1.000662             1  2.912385
#
# [952 rows x 8 columns]

# %%
data.loc['2015, 06, 23': '2015-06-29']
# Out:
#                  Volume  Adj Close      SMA20     SMA120  price_yesterday  \
# Date
# 2015-06-23  121075600.0  28.906944  29.281624  28.161932        29.038931
# 2015-06-24  221123600.0  29.152712  29.236909  28.197244        28.906944
# 2015-06-25  127752400.0  29.013899  29.188210  28.233374        29.152712
# 2015-06-26  176267200.0  28.843229  29.148046  28.273876        29.013899
# 2015-06-29  196645600.0  28.338049  29.079665  28.310149        28.843229
#
#               change  invested_SMA  buy_and_hold
# Date
# 2015-06-23  0.995455             1      1.160210
# 2015-06-24  1.008502             1      1.170074
# 2015-06-25  0.995238             1      1.164503
# 2015-06-26  0.994118             1      1.157653
# 2015-06-29  0.982485             1      1.137377

# %%
data
# Out:
#                  Volume   Adj Close       SMA20     SMA120  price_yesterday  \
# Date
# 2014-12-31  165613600.0   24.915262         NaN        NaN              NaN
# 2015-01-02  212818400.0   24.678251         NaN        NaN        24.915262
# 2015-01-05  257142000.0   23.983025         NaN        NaN        24.678251
# 2015-01-06  263188400.0   23.985279         NaN        NaN        23.983025
# 2015-01-07  160423600.0   24.321608         NaN        NaN        23.985279
# ...                 ...         ...         ...        ...              ...
# 2020-08-31  225702700.0  127.677971  116.445662  84.878069       123.490158
# 2020-09-01  151948100.0  132.763748  117.668239  85.475046       127.677971
# 2020-09-02  200119000.0  130.013062  118.733652  85.988072       132.763748
# 2020-09-03  257599600.0  119.604111  119.088986  86.487739       130.013062
# 2020-09-04  332607200.0  119.683266  119.576163  86.966211       119.604111
#
#               change  invested_SMA  buy_and_hold
# Date
# 2014-12-31       NaN             0           NaN
# 2015-01-02  0.990487             0      0.990487
# 2015-01-05  0.971828             0      0.962584
# 2015-01-06  1.000094             0      0.962674
# 2015-01-07  1.014022             0      0.976173
# ...              ...           ...           ...
# 2020-08-31  1.033912             1      5.124488
# 2020-09-01  1.039833             1      5.328611
# 2020-09-02  0.979281             1      5.218210
# 2020-09-03  0.919939             1      4.800436
# 2020-09-04  1.000662             1      4.803613
#
# [1431 rows x 8 columns]

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((10, 1), (0, 0), rowspan = 4, colspan = 1, title = ticker)
ax2 = plt.subplot2grid((10, 1), (5, 0), rowspan = 2, colspan = 1, sharex = ax1)
ax3 = plt.subplot2grid((10, 1), (8, 0), rowspan = 2, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price', alpha = 0.75)
ax1.plot(data['SMA20'], label = 'SMA20')
ax1.plot(data['SMA120'], label = 'SMA120')

ax2.bar(data.index, data['Volume'], label = 'Volume')

ax3.plot(data['buy_and_hold'], label = 'Buy and Hold')
ax3.plot(sma['return'], label = 'SMA')

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y, %m'))

ax3.set_xlabel('Date (Year - Month)')

ax1.legend()
ax2.legend(loc = 'upper right')
ax3.legend()

# Hold and Buy strategy has outperformed the strategy based on buying when SMA20 is greater than SMA120.

# %% [markdown]
# #### Exponential weighted moving average strategy:

# %%
data['EWM12'] = data['Adj Close'].ewm(span =12, adjust = False).mean()
data['EWM26'] = data['Adj Close'].ewm(span =26, adjust = False).mean()

# More weight is assigned in weighted moving average such as EWM based on timing or frequency. For instance, more
# recent prices could be assigned more weight as compared to relatively old prices.

# %%
data
# Out:
#                  Volume   Adj Close       SMA20     SMA120  price_yesterday  \
# Date
# 2014-12-31  165613600.0   24.915258         NaN        NaN              NaN
# 2015-01-02  212818400.0   24.678251         NaN        NaN        24.915258
# 2015-01-05  257142000.0   23.983023         NaN        NaN        24.678251
# 2015-01-06  263188400.0   23.985285         NaN        NaN        23.983023
# 2015-01-07  160423600.0   24.321611         NaN        NaN        23.985285
# ...                 ...         ...         ...        ...              ...
# 2020-08-31  225702700.0  127.677971  116.445661  84.878069       123.490166
# 2020-09-01  151948100.0  132.763718  117.668237  85.475045       127.677971
# 2020-09-02  200119000.0  130.013092  118.733651  85.988071       132.763718
# 2020-09-03  257599600.0  119.604111  119.088986  86.487738       130.013092
# 2020-09-04  332607200.0  119.683273  119.576164  86.966210       119.604111
#
#               change  invested_SMA  buy_and_hold       EWM12       EWM26
# Date
# 2014-12-31       NaN             0           NaN   24.915258   24.915258
# 2015-01-02  0.990487             0      0.990487   24.878796   24.897702
# 2015-01-05  0.971828             0      0.962584   24.740985   24.829948
# 2015-01-06  1.000094             0      0.962675   24.624723   24.767381
# 2015-01-07  1.014022             0      0.976173   24.578090   24.734361
# ...              ...           ...           ...         ...         ...
# 2020-08-31  1.033912             1      5.124489  120.683730  113.711707
# 2020-09-01  1.039833             1      5.328611  122.542190  115.122967
# 2020-09-02  0.979282             1      5.218212  123.691559  116.225939
# 2020-09-03  0.919939             1      4.800436  123.062721  116.476174
# 2020-09-04  1.000662             1      4.803614  122.542806  116.713737
#
# [1431 rows x 10 columns]

# %%
data['invested_EWM'] = np.where(data['EWM12'] > data['EWM26'], 1, 0)
data
# Out:
#                  Volume   Adj Close       SMA20     SMA120  price_yesterday  \
# Date
# 2014-12-31  165613600.0   24.915258         NaN        NaN              NaN
# 2015-01-02  212818400.0   24.678251         NaN        NaN        24.915258
# 2015-01-05  257142000.0   23.983023         NaN        NaN        24.678251
# 2015-01-06  263188400.0   23.985285         NaN        NaN        23.983023
# 2015-01-07  160423600.0   24.321611         NaN        NaN        23.985285
# ...                 ...         ...         ...        ...              ...
# 2020-08-31  225702700.0  127.677971  116.445661  84.878069       123.490166
>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ewm['return'] = np.cumprod(ewm['change'])
#                  Volume   Adj Close       SMA20     SMA120  price_yesterday  \
# Date
# 2015-01-23  185859200.0   25.502138         NaN        NaN        25.371220
# 2015-01-26  222460000.0   25.529228         NaN        NaN        25.502138
# 2015-01-27  382274800.0   24.635363         NaN        NaN        25.529228
# 2015-01-28  585908400.0   26.028072         NaN        NaN        24.635363
# 2015-01-29  337745600.0   26.838415   24.897766        NaN        26.028072
# ...                 ...         ...         ...        ...              ...
# 2020-08-31  225702700.0  127.677971  116.445661  84.878069       123.490166
# 2020-09-01  151948100.0  132.763718  117.668237  85.475045       127.677971
# 2020-09-02  200119000.0  130.013092  118.733651  85.988071       132.763718
# 2020-09-03  257599600.0  119.604111  119.088986  86.487738       130.013092
# 2020-09-04  332607200.0  119.683273  119.576164  86.966210       119.604111
#
#               change  invested_SMA  buy_and_hold       EWM12       EWM26  \
# Date
# 2015-01-23  1.005160             0      1.023555   24.826916   24.791474
# 2015-01-26  1.001062             0      1.024642   24.934964   24.846122
# 2015-01-27  0.964987             0      0.988766   24.888871   24.830511
# 2015-01-28  1.056533             0      1.044664   25.064133   24.919219
# 2015-01-29  1.031133             0      1.077188   25.337100   25.061382
# ...              ...           ...           ...         ...         ...
# 2020-08-31  1.033912             1      5.124489  120.683730  113.711707
# 2020-09-01  1.039833             1      5.328611  122.542190  115.122967
# 2020-09-02  0.979282             1      5.218212  123.691559  116.225939
# 2020-09-03  0.919939             1      4.800436  123.062721  116.476174
# 2020-09-04  1.000662             1      4.803614  122.542806  116.713737
#
#             invested_EWM    return
# Date
# 2015-01-23             1  1.005160
# 2015-01-26             1  1.006228
# 2015-01-27             1  0.970996
# 2015-01-28             1  1.025890
# 2015-01-29             1  1.057829
# ...                  ...       ...
# 2020-08-31             1  7.507869
# 2020-09-01             1  7.806927
# 2020-09-02             1  7.645181
# 2020-09-03             1  7.033100
# 2020-09-04             1  7.037755
#
# [988 rows x 12 columns]

# %%
#%matplotlib notebook
plt.figure(figsize=(14, 10))

ax1 = plt.subplot2grid((10, 1), (0, 0), rowspan = 4, colspan = 1, title = ticker)
ax2 = plt.subplot2grid((10, 1), (5, 0), rowspan = 2, colspan = 1, sharex = ax1)
ax3 = plt.subplot2grid((10, 1), (8, 0), rowspan = 3, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price')
ax1.plot(data['SMA20'], label = 'SMA20')
ax1.plot(data['SMA120'], label = 'SMA120')
ax1.plot(data['EWM12'], label = 'EWM12')
ax1.plot(data['EWM26'], label = 'EWM26')

ax2.bar(data.index, data['Volume'], label = 'Volume')

ax3.plot(data['buy_and_hold'], label = 'Buy and Hold')
ax3.plot(sma['return'], label = 'SMA')
ax3.plot(ewm['return'], label = 'EWM')

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y, %m'))

ax3.set_xlabel('Date (Year - Month)')

ax1.legend(fontsize = 10)
ax2.legend(fontsize = 10, loc = 'upper right')
ax3.legend(fontsize = 8)
plt.savefig('ewm.png')
plt.show()

# from the first graph, we can compare EWM12 with EWM26. When the EWM12 goves above EWM26, it is a buy signal and
# we buy. Similarly, we EWM12 goves below EWM26, it is a sell signal and we sell. Based on EWM strategy of buy and
# sell, we generate the return graphed in the last graph, which shows that a higher return has been generated 
# following EWM strategy as compared to SMA and Buy and Hold strategies.

# EWM strategy generates more timely signals to buy and sell as compared to SMA strategy. Therefore, it generates
# superior returns.

# %%
# pip install ipywidgets

# %%
# jupyter nbextension enable --py widgetsnbextension

# %% [markdown]
# #### Multiple stocks (assets):

# %%
tickers = ['AAPL', 'KO', 'MSFT', 'TSLA', 'AMZN']

# %%
for ticker in tickers:
    data = web.DataReader(ticker, 'yahoo', start, end)
    data = data.drop(columns = ['High', 'Low', 'Open', 'Close'])
    data['SMA20'] = data['Adj Close'].rolling(20).mean()
    data['SMA120'] = data['Adj Close'].rolling(120).mean()
    data['EWM12'] = data['Adj Close'].ewm(span = 12, adjust = False).mean()
    data['EWM26'] = data['Adj Close'].ewm(span = 26, adjust = False).mean()
    data['price_yesterday'] = data['Adj Close'].shift(1)
    data['change'] = data['Adj Close'] / data['price_yesterday']
    data['invested_SMA'] = np.where(data['SMA20'] > data['SMA120'], 1, 0)
    data['invested_EWM'] = np.where(data['EWM12'] > data['EWM26'], 1, 0)
    sma = data[data['invested_SMA'] == 1] # only take those rows from dataframe, sma, where the condition is satis-
     # fied and store them in new dataframe, sma. The condition is: data['invested_SMA'] == 1.
    ewm = data[data['invested_EWM'] == 1]
    data['buy_and_hold'] = np.cumprod(data['change'])
    sma['return'] = np.cumprod(sma['change']) # sma['change'] is the same column as data['change'] except that
    # data['change'] has all the values whereas sma['change'] has only the values where the condition was met.
    ewm['return'] = np.cumprod(ewm['change'])
    print(ticker)
    print('Buy and Hold return: ' + str(data['buy_and_hold'][-1])) # two strings concatenated.
    print('SMA return: ' + str(sma['return'][-1]))
    print('EWM return: ' + str(ewm['return'][-1]))
# Out:
# <ipython-input-151-d7840fbb43ee>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sma['return'] = np.cumprod(sma['change']) # sma['change'] is the same column as data['change'] except that
# <ipython-input-151-d7840fbb43ee>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ewm['return'] = np.cumprod(ewm['change'])
# GOOG
# Buy and Hold return: 3.030790645284146
# SMA return: 1.4769113792281667
# EWM return: 2.919594967992309
# AMZN
# Buy and Hold return: 10.615821016251603
# SMA return: 5.740552451089567
# EWM return: 11.53887426791993
# AAPL
# Buy and Hold return: 4.803613996389286
# SMA return: 2.9123862998792913
# EWM return: 7.037754364482569

# %% [markdown]
# ### Conclusion:
# ##### No strategy gurantees favorable outcome. No strategy is all the time winner for all the firms.
# ##### Finance is not a physical science. Many factors are at play at once.
# ##### A company crashed in 2020 thought all the charts generating buy signals for it.
# ##### Buy and sell signals based on moving averages will depend on your belief in momentum vs contrarian strategy.
# ##### The moving average is just one of the many techniques of technical analysis (chartists). The other techniques are candlesticks, relative strength etc.
# ##### Fundamental analysis is another stream of analysis, where undervalued stocks are searched rather than making decisions entirely on the basis of trends shown in charts and graphs. This is the topic of our next section in this course.

# %%
data['buy_and_hold'][-1] # the last value in 'buy_and_hold' column in the data frame, data, which is 10.61 for AMZN which 
# means $1 invested at the start of the period would have grown to $ 4.8 at the end of period using buy and hold
# strategy.
# Out:
# 4.803613996389286

# %%
data['buy_and_hold']
# Out:
# Date
# 2014-12-31         NaN
# 2015-01-02    0.990488
# 2015-01-05    0.962584
# 2015-01-06    0.962675
# 2015-01-07    0.976173
#                 ...
# 2020-08-31    5.124491
# 2020-09-01    5.328612
# 2020-09-02    5.218212
# 2020-09-03    4.800437
# 2020-09-04    4.803614
# Name: buy_and_hold, Length: 1431, dtype: float64

# %%
sma['return'][-1] # interpret same as above expcept that this is SMA strategy.
# Out:
# 2.9123862998792913

# %%
ewm['return'][-1] # interpret same as above expcept that this is SMA strategy.
# Out:
# 7.037754364482569

# %%
type(ewm['return']) # [-1] can be applied to obtain the last value from the series as done above.
# Out:
# pandas.core.series.Series

# %%
data # just to see the data for various reasons when working at different things.
# Out:
#                  Volume   Adj Close       SMA20     SMA120       EWM12  \
# Date
# 2014-12-31  165613600.0   24.915255         NaN        NaN   24.915255
# 2015-01-02  212818400.0   24.678253         NaN        NaN   24.878793
# 2015-01-05  257142000.0   23.983021         NaN        NaN   24.740982
# 2015-01-06  263188400.0   23.985281         NaN        NaN   24.624720
# 2015-01-07  160423600.0   24.321609         NaN        NaN   24.578088
# ...                 ...         ...         ...        ...         ...
# 2020-08-31  225702700.0  127.677994  116.445662  84.878069  120.683734
# 2020-09-01  151948100.0  132.763733  117.668238  85.475045  122.542196
# 2020-09-02  200119000.0  130.013077  118.733652  85.988071  123.691562
# 2020-09-03  257599600.0  119.604118  119.088987  86.487738  123.062725
# 2020-09-04  332607200.0  119.683266  119.576165  86.966210  122.542808
#
#                  EWM26  price_yesterday    change  invested_SMA  invested_EWM  \
# Date
# 2014-12-31   24.915255              NaN       NaN             0             0
# 2015-01-02   24.897699        24.915255  0.990488             0             0
# 2015-01-05   24.829945        24.678253  0.971828             0             0
# 2015-01-06   24.767377        23.983021  1.000094             0             0
# 2015-01-07   24.734357        23.985281  1.014022             0             0
# ...                ...              ...       ...           ...           ...
# 2020-08-31  113.711708       123.490173  1.033912             1             1
# 2020-09-01  115.122970       127.677994  1.039833             1             1
# 2020-09-02  116.225940       132.763733  0.979282             1             1
# 2020-09-03  116.476176       130.013077  0.919939             1             1
# 2020-09-04  116.713738       119.604118  1.000662             1             1
#
#             buy_and_hold
# Date
# 2014-12-31           NaN
# 2015-01-02      0.990488
# 2015-01-05      0.962584
# 2015-01-06      0.962675
# 2015-01-07      0.976173
# ...                  ...
# 2020-08-31      5.124491
# 2020-09-01      5.328612
# 2020-09-02      5.218212
# 2020-09-03      4.800437
# 2020-09-04      4.803614
#
# [1431 rows x 11 columns]
